# %% [markdown]
# # English Premier League (EPL)
#
# A total of four csv files have been sourced and downloaded from Kaggle (https://www.kaggle.com/krishanthbarkav/english-premier-leagueepl-player-statistics) containing EPL statistics from 2015 - 2019.

# %% [markdown]
# ## Extract

# %%
# Dependencies and Setup
# -------------------------------------------
import pandas as pd
import numpy as np

# %%
# Show path to csv files
# -------------------------------------------
data_15_16_path = ("Resources/OriginalData/pl_15-16.csv")
data_16_17_path = ("Resources/OriginalData/pl_15-16.csv")
data_17_18_path = ("Resources/OriginalData/pl_15-16.csv")
data_18_19_path = ("Resources/OriginalData/pl_15-16.csv")
html_request_path = ('Resources/Player_complete_nationality.csv')

# %%
# Read csv files through Pandas
# -------------------------------------------
data_15_16 = pd.read_csv(data_15_16_path)
data_16_17 = pd.read_csv(data_16_17_path)
data_17_18 = pd.read_csv(data_17_18_path)
data_18_19 = pd.read_csv(data_18_19_path)
html_request = pd.read_csv(html_request_path)

# %% [markdown]
# ## Transform

# %%
# Dropping Unnamed: 0 column
# -------------------------------------------
del data_15_16["Unnamed: 0"]
del data_16_17["Unnamed: 0"]
del data_17_18["Unnamed: 0"]
del data_18_19["Unnamed: 0"]

# %%
# Rename columns with special characters to assist with the import of headers to SQL
# -------------------------------------------
data_15_16.rename(columns={'Tackle success %':'Tackle success Percentage', 'Successful 50/50s':'Successful 50_50s', 'Cross accuracy %':'Cross accuracy Percentage', 'Shooting accuracy %':'Shooting accuracy Percentage'}, inplace=True)
data_16_17.rename(columns={'Tackle success %':'Tackle success Percentage', 'Successful 50/50s':'Successful 50_50s', 'Cross accuracy %':'Cross accuracy Percentage', 'Shooting accuracy %':'Shooting accuracy Percentage'}, inplace=True)
data_17_18.rename(columns={'Tackle success %':'Tackle success Percentage', 'Successful 50/50s':'Successful 50_50s', 'Cross accuracy %':'Cross accuracy Percentage', 'Shooting accuracy %':'Shooting accuracy Percentage'}, inplace=True)
data_18_19.rename(columns={'Tackle success %':'Tackle success Percentage', 'Successful 50/50s':'Successful 50_50s', 'Cross accuracy %':'Cross accuracy Percentage', 'Shooting accuracy %':'Shooting accuracy Percentage'}, inplace=True)

# %%
# Rename columns to include relevant Year from associated csv files
# -------------------------------------------
data_15_16 = data_15_16.rename(columns={col: col + " 2015_2016" for col in data_15_16.columns if col not in ['Name', 'Position']})
data_16_17 = data_16_17.rename(columns={col: col + " 2016_2017" for col in data_16_17.columns if col not in ['Name', 'Position']})
data_17_18 = data_17_18.rename(columns={col: col + " 2017_2018" for col in data_17_18.columns if col not in ['Name', 'Position']})
data_18_19 = data_18_19.rename(columns={col: col + " 2018_2019" for col in data_18_19.columns if col not in ['Name', 'Position']})

# %%
# Merge DataFrame on Name and Position
# -------------------------------------------
complete_stats = pd.merge(data_15_16, data_16_17, on = ["Name", "Position"], how = "outer")
complete_stats = pd.merge(complete_stats, data_17_18, on = ["Name", "Position"], how = "outer")
complete_stats = pd.merge(complete_stats, data_18_19, on = ["Name", "Position"], how = "outer")

# %%
# Remove spaces in columns name and replace with "_"
# -------------------------------------------
complete_stats.columns = complete_stats.columns.str.replace(' ','_')

# %%
complete_stats.columns = complete_stats.columns.str.lower()

# %%
# Create list of columns which contain % and convert dtype to Float
# -------------------------------------------
percentages= ['tackle_success_percentage_2015_2016',
              'tackle_success_percentage_2016_2017',
              'tackle_success_percentage_2017_2018',
              'tackle_success_percentage_2018_2019',
              'cross_accuracy_percentage_2015_2016',
              'cross_accuracy_percentage_2016_2017',
              'cross_accuracy_percentage_2017_2018',
              'cross_accuracy_percentage_2018_2019',
              'shooting_accuracy_percentage_2015_2016',
              'shooting_accuracy_percentage_2016_2017',
              'shooting_accuracy_percentage_2017_2018',
              'shooting_accuracy_percentage_2018_2019',]

for col in percentages:
    complete_stats[col] = complete_stats[col].str.strip('%').astype('float64')

# %%
# Loop through columns 2 onwards, remove ',' and convert to Float
# -------------------------------------------
for col1 in complete_stats.columns[2:]:
    print(col1)
    if complete_stats[col1].dtype == np.object:
        complete_stats[col1] = complete_stats[col1].str.replace(',','').astype('float64')
# Out:
# appearances_2015_2016
# clean_sheets_2015_2016
# goals_conceded_2015_2016
# tackles_2015_2016
# tackle_success_percentage_2015_2016
# last_man_tackles_2015_2016
# blocked_shots_2015_2016
# interceptions_2015_2016
# clearances_2015_2016
# headed_clearance_2015_2016
# clearances_off_line_2015_2016
# recoveries_2015_2016
# duels_won_2015_2016
# duels_lost_2015_2016
# successful_50_50s_2015_2016
# aerial_battles_won_2015_2016
# aerial_battles_lost_2015_2016
# own_goals_2015_2016
# errors_leading_to_goal_2015_2016
# assists_2015_2016
# passes_2015_2016
# passes_per_match_2015_2016
# big_chances_created_2015_2016
# crosses_2015_2016
# cross_accuracy_percentage_2015_2016
# through_balls_2015_2016
# accurate_long_balls_2015_2016
# yellow_cards_2015_2016
# red_cards_2015_2016
# fouls_2015_2016
# offsides_2015_2016
# goals_2015_2016
# headed_goals_2015_2016
# goals_with_right_foot_2015_2016
# goals_with_left_foot_2015_2016
# hit_woodwork_2015_2016
# goals_per_match_2015_2016
# penalties_scored_2015_2016
# freekicks_scored_2015_2016
# shots_2015_2016
# shots_on_target_2015_2016
# shooting_accuracy_percentage_2015_2016
# big_chances_missed_2015_2016
# saves_2015_2016
# penalties_saved_2015_2016
# punches_2015_2016
# high_claims_2015_2016
# catches_2015_2016
# sweeper_clearances_2015_2016
# throw_outs_2015_2016
# goal_kicks_2015_2016
# appearances_2016_2017
# clean_sheets_2016_2017
# goals_conceded_2016_2017
# tackles_2016_2017
# tackle_success_percentage_2016_2017
# last_man_tackles_2016_2017
# blocked_shots_2016_2017
# interceptions_2016_2017
# clearances_2016_2017
# headed_clearance_2016_2017
# clearances_off_line_2016_2017
# recoveries_2016_2017
# duels_won_2016_2017
# duels_lost_2016_2017
# successful_50_50s_2016_2017
# aerial_battles_won_2016_2017
# aerial_battles_lost_2016_2017
# own_goals_2016_2017
# errors_leading_to_goal_2016_2017
# assists_2016_2017
# passes_2016_2017
# passes_per_match_2016_2017
# big_chances_created_2016_2017
# crosses_2016_2017
# cross_accuracy_percentage_2016_2017
# through_balls_2016_2017
# accurate_long_balls_2016_2017
# yellow_cards_2016_2017
# red_cards_2016_2017
# fouls_2016_2017
# offsides_2016_2017
# goals_2016_2017
# headed_goals_2016_2017
# goals_with_right_foot_2016_2017
# goals_with_left_foot_2016_2017
# hit_woodwork_2016_2017
# goals_per_match_2016_2017
# penalties_scored_2016_2017
# freekicks_scored_2016_2017
# shots_2016_2017
# shots_on_target_2016_2017
# shooting_accuracy_percentage_2016_2017
# big_chances_missed_2016_2017
# saves_2016_2017
# penalties_saved_2016_2017
# punches_2016_2017
# high_claims_2016_2017
# catches_2016_2017
# sweeper_clearances_2016_2017
# throw_outs_2016_2017
# goal_kicks_2016_2017
# appearances_2017_2018
# clean_sheets_2017_2018
# goals_conceded_2017_2018
# tackles_2017_2018
# tackle_success_percentage_2017_2018
# last_man_tackles_2017_2018
# blocked_shots_2017_2018
# interceptions_2017_2018
# clearances_2017_2018
# headed_clearance_2017_2018
# clearances_off_line_2017_2018
# recoveries_2017_2018
# duels_won_2017_2018
# duels_lost_2017_2018
# successful_50_50s_2017_2018
# aerial_battles_won_2017_2018
# aerial_battles_lost_2017_2018
# own_goals_2017_2018
# errors_leading_to_goal_2017_2018
# assists_2017_2018
# passes_2017_2018
# passes_per_match_2017_2018
# big_chances_created_2017_2018
# crosses_2017_2018
# cross_accuracy_percentage_2017_2018
# through_balls_2017_2018
# accurate_long_balls_2017_2018
# yellow_cards_2017_2018
# red_cards_2017_2018
# fouls_2017_2018
# offsides_2017_2018
# goals_2017_2018
# headed_goals_2017_2018
# goals_with_right_foot_2017_2018
# goals_with_left_foot_2017_2018
# hit_woodwork_2017_2018
# goals_per_match_2017_2018
# penalties_scored_2017_2018
# freekicks_scored_2017_2018
# shots_2017_2018
# shots_on_target_2017_2018
# shooting_accuracy_percentage_2017_2018
# big_chances_missed_2017_2018
# saves_2017_2018
# penalties_saved_2017_2018
# punches_2017_2018
# high_claims_2017_2018
# catches_2017_2018
# sweeper_clearances_2017_2018
# throw_outs_2017_2018
# goal_kicks_2017_2018
# appearances_2018_2019
# clean_sheets_2018_2019
# goals_conceded_2018_2019
# tackles_2018_2019
# tackle_success_percentage_2018_2019
# last_man_tackles_2018_2019
# blocked_shots_2018_2019
# interceptions_2018_2019
# clearances_2018_2019
# headed_clearance_2018_2019
# clearances_off_line_2018_2019
# recoveries_2018_2019
# duels_won_2018_2019
# duels_lost_2018_2019
# successful_50_50s_2018_2019
# aerial_battles_won_2018_2019
# aerial_battles_lost_2018_2019
# own_goals_2018_2019
# errors_leading_to_goal_2018_2019
# assists_2018_2019
# passes_2018_2019
# passes_per_match_2018_2019
# big_chances_created_2018_2019
# crosses_2018_2019
# cross_accuracy_percentage_2018_2019
# through_balls_2018_2019
# accurate_long_balls_2018_2019
# yellow_cards_2018_2019
# red_cards_2018_2019
# fouls_2018_2019
# offsides_2018_2019
# goals_2018_2019
# headed_goals_2018_2019
# goals_with_right_foot_2018_2019
# goals_with_left_foot_2018_2019
# hit_woodwork_2018_2019
# goals_per_match_2018_2019
# penalties_scored_2018_2019
# freekicks_scored_2018_2019
# shots_2018_2019
# shots_on_target_2018_2019
# shooting_accuracy_percentage_2018_2019
# big_chances_missed_2018_2019
# saves_2018_2019
# penalties_saved_2018_2019
# punches_2018_2019
# high_claims_2018_2019
# catches_2018_2019
# sweeper_clearances_2018_2019
# throw_outs_2018_2019
# goal_kicks_2018_2019

# %%
# Check
# -------------------------------------------
np.object
# Out:
# object

# %%
# Replacing NaN with 0
# -------------------------------------------
complete_stats.fillna(0,inplace=True)

# %%
# Find the unique elements of an array and returns the sorted unique elements of an array.
# -------------------------------------------
complete_stats['passes_2018_2019'].unique
# Out:
# <bound method Series.unique of 0      119.0
# 1      938.0
# 2      526.0
# 3        0.0
# 4       10.0
#        ...
# 752    263.0
# 753      0.0
# 754    736.0
# 755      0.0
# 756      0.0
# Name: passes_2018_2019, Length: 757, dtype: float64>

# %%
# Set Name column as index
# -------------------------------------------
complete_stats.set_index('name', inplace=True)

# %%
# pd.set_option('display.max_rows', None)

# %%
# Check
# -------------------------------------------
# complete_data.dtypes
complete_stats['tackle_success_percentage_2015_2016'].dtype == np.float64
# Out:
# True

# %%
# Save DataFrame to csv file
# -------------------------------------------
complete_stats.to_csv('Resources/player_stats_complete.csv')

# %%
complete_stats['average_appearances'] = complete_stats [['appearances_2015_2016','appearances_2016_2017','appearances_2017_2018','appearances_2018_2019',]].mean(axis=1)
complete_stats['average_clean_sheets'] = complete_stats [['clean_sheets_2015_2016','clean_sheets_2016_2017','clean_sheets_2017_2018','clean_sheets_2018_2019',]].mean(axis=1)
complete_stats['average_goals_conceded'] = complete_stats [['goals_conceded_2015_2016','goals_conceded_2016_2017','goals_conceded_2017_2018','goals_conceded_2018_2019',]].mean(axis=1)
complete_stats['average_tackles'] = complete_stats [['tackles_2015_2016','tackles_2016_2017','tackles_2017_2018','tackles_2018_2019',]].mean(axis=1)
complete_stats['average_tackle_success_percentage'] = complete_stats [['tackle_success_percentage_2015_2016','tackle_success_percentage_2016_2017','tackle_success_percentage_2017_2018','tackle_success_percentage_2018_2019',]].mean(axis=1)
complete_stats['average_last_man_tackles'] = complete_stats [['last_man_tackles_2015_2016','last_man_tackles_2016_2017','last_man_tackles_2017_2018','last_man_tackles_2018_2019',]].mean(axis=1)
complete_stats['average_blocked_shots'] = complete_stats [['blocked_shots_2015_2016','blocked_shots_2016_2017','blocked_shots_2017_2018','blocked_shots_2018_2019',]].mean(axis=1)
complete_stats['average_interceptions'] = complete_stats [['interceptions_2015_2016','interceptions_2016_2017','interceptions_2017_2018','interceptions_2018_2019',]].mean(axis=1)
complete_stats['average_clearances'] = complete_stats [['clearances_2015_2016','clearances_2016_2017','clearances_2017_2018','clearances_2018_2019',]].mean(axis=1)
complete_stats['average_headed_clearance'] = complete_stats [['headed_clearance_2015_2016','headed_clearance_2016_2017','headed_clearance_2017_2018','headed_clearance_2018_2019',]].mean(axis=1)
complete_stats['average_clearances_off_line'] = complete_stats [['clearances_off_line_2015_2016','clearances_off_line_2016_2017','clearances_off_line_2017_2018','clearances_off_line_2018_2019',]].mean(axis=1)
complete_stats['average_recoveries'] = complete_stats [['recoveries_2015_2016','recoveries_2016_2017','recoveries_2017_2018','recoveries_2018_2019',]].mean(axis=1)
complete_stats['average_duels_won'] = complete_stats [['duels_won_2015_2016','duels_won_2016_2017','duels_won_2017_2018','duels_won_2018_2019',]].mean(axis=1)
complete_stats['average_duels_lost'] = complete_stats [['duels_lost_2015_2016','duels_lost_2016_2017','duels_lost_2017_2018','duels_lost_2018_2019',]].mean(axis=1)
complete_stats['average_successful_50_50s'] = complete_stats [['successful_50_50s_2015_2016','successful_50_50s_2016_2017','successful_50_50s_2017_2018','successful_50_50s_2018_2019',]].mean(axis=1)
complete_stats['average_aerial_battles_won'] = complete_stats [['aerial_battles_won_2015_2016','aerial_battles_won_2016_2017','aerial_battles_won_2017_2018','aerial_battles_won_2018_2019',]].mean(axis=1)
complete_stats['average_aerial_battles_lost'] = complete_stats [['aerial_battles_lost_2015_2016','aerial_battles_lost_2016_2017','aerial_battles_lost_2017_2018','aerial_battles_lost_2018_2019',]].mean(axis=1)
complete_stats['average_own_goals'] = complete_stats [['own_goals_2015_2016','own_goals_2016_2017','own_goals_2017_2018','own_goals_2018_2019',]].mean(axis=1)
complete_stats['average_errors_leading_to_goal'] = complete_stats [['errors_leading_to_goal_2015_2016','errors_leading_to_goal_2016_2017','errors_leading_to_goal_2017_2018','errors_leading_to_goal_2018_2019',]].mean(axis=1)
complete_stats['average_assists'] = complete_stats [['assists_2015_2016','assists_2016_2017','assists_2017_2018','assists_2018_2019',]].mean(axis=1)
complete_stats['average_passes'] = complete_stats [['passes_2015_2016','passes_2016_2017','passes_2017_2018','passes_2018_2019',]].mean(axis=1)
complete_stats['average_passes_per_match'] = complete_stats [['passes_per_match_2015_2016','passes_per_match_2016_2017','passes_per_match_2017_2018','passes_per_match_2018_2019',]].mean(axis=1)
complete_stats['average_big_chances_created'] = complete_stats [['big_chances_created_2015_2016','big_chances_created_2016_2017','big_chances_created_2017_2018','big_chances_created_2018_2019',]].mean(axis=1)
complete_stats['average_crosses'] = complete_stats [['crosses_2015_2016','crosses_2016_2017','crosses_2017_2018','crosses_2018_2019',]].mean(axis=1)
complete_stats['average_cross_accuracy_percentage'] = complete_stats [['cross_accuracy_percentage_2015_2016','cross_accuracy_percentage_2016_2017','cross_accuracy_percentage_2017_2018','cross_accuracy_percentage_2018_2019',]].mean(axis=1)
complete_stats['average_through_balls'] = complete_stats [['through_balls_2015_2016','through_balls_2016_2017','through_balls_2017_2018','through_balls_2018_2019',]].mean(axis=1)
complete_stats['average_accurate_long_balls'] = complete_stats [['accurate_long_balls_2015_2016','accurate_long_balls_2016_2017','accurate_long_balls_2017_2018','accurate_long_balls_2018_2019',]].mean(axis=1)
complete_stats['average_yellow_cards'] = complete_stats [['yellow_cards_2015_2016','yellow_cards_2016_2017','yellow_cards_2017_2018','yellow_cards_2018_2019',]].mean(axis=1)
complete_stats['average_fouls'] = complete_stats [['fouls_2015_2016','fouls_2016_2017','fouls_2017_2018','fouls_2018_2019',]].mean(axis=1)
complete_stats['average_offsides'] = complete_stats [['offsides_2015_2016','offsides_2016_2017','offsides_2017_2018','offsides_2018_2019',]].mean(axis=1)
complete_stats['average_goals'] = complete_stats [['goals_2015_2016','goals_2016_2017','goals_2017_2018','goals_2018_2019',]].mean(axis=1)
complete_stats['average_headed_goals'] = complete_stats [['headed_goals_2015_2016','headed_goals_2016_2017','headed_goals_2017_2018','headed_goals_2018_2019',]].mean(axis=1)
complete_stats['average_goals_with_right_foot'] = complete_stats [['goals_with_right_foot_2015_2016','goals_with_right_foot_2016_2017','goals_with_right_foot_2017_2018','goals_with_right_foot_2018_2019',]].mean(axis=1)
complete_stats['average_goals_with_left_foot'] = complete_stats [['goals_with_left_foot_2015_2016','goals_with_left_foot_2016_2017','goals_with_left_foot_2017_2018','goals_with_left_foot_2018_2019',]].mean(axis=1)
complete_stats['average_hit_woodwork'] = complete_stats [['hit_woodwork_2015_2016','hit_woodwork_2016_2017','hit_woodwork_2017_2018','hit_woodwork_2018_2019',]].mean(axis=1)
complete_stats['average_goals_per_match'] = complete_stats [['goals_per_match_2015_2016','goals_per_match_2016_2017','goals_per_match_2017_2018','goals_per_match_2018_2019',]].mean(axis=1)
complete_stats['average_penalties_scored'] = complete_stats [['penalties_scored_2015_2016','penalties_scored_2016_2017','penalties_scored_2017_2018','penalties_scored_2018_2019',]].mean(axis=1)
complete_stats['average_freekicks_scored'] = complete_stats [['freekicks_scored_2015_2016','freekicks_scored_2016_2017','freekicks_scored_2017_2018','freekicks_scored_2018_2019',]].mean(axis=1)
complete_stats['average_shots'] = complete_stats [['shots_2015_2016','shots_2016_2017','shots_2017_2018','shots_2018_2019',]].mean(axis=1)
complete_stats['average_shots_on_target'] = complete_stats [['shots_on_target_2015_2016','shots_on_target_2016_2017','shots_on_target_2017_2018','shots_on_target_2018_2019',]].mean(axis=1)
complete_stats['average_shooting_accuracy_percentage'] = complete_stats [['shooting_accuracy_percentage_2015_2016','shooting_accuracy_percentage_2016_2017','shooting_accuracy_percentage_2017_2018','shooting_accuracy_percentage_2018_2019',]].mean(axis=1)
complete_stats['average_big_chances_missed'] = complete_stats [['big_chances_missed_2015_2016','big_chances_missed_2016_2017','big_chances_missed_2017_2018','big_chances_missed_2018_2019',]].mean(axis=1)
complete_stats['average_saves'] = complete_stats [['saves_2015_2016','saves_2016_2017','saves_2017_2018','saves_2018_2019',]].mean(axis=1)
complete_stats['average_penalties_saved'] = complete_stats [['penalties_saved_2015_2016','penalties_saved_2016_2017','penalties_saved_2017_2018','penalties_saved_2018_2019',]].mean(axis=1)
complete_stats['average_punches'] = complete_stats [['punches_2015_2016','punches_2016_2017','punches_2017_2018','punches_2018_2019',]].mean(axis=1)
complete_stats['average_high_claims'] = complete_stats [['high_claims_2015_2016','high_claims_2016_2017','high_claims_2017_2018','high_claims_2018_2019',]].mean(axis=1)
complete_stats['average_catches'] = complete_stats [['catches_2015_2016','catches_2016_2017','catches_2017_2018','catches_2018_2019',]].mean(axis=1)
complete_stats['average_sweeper_clearances'] = complete_stats [['sweeper_clearances_2015_2016','sweeper_clearances_2016_2017','sweeper_clearances_2017_2018','sweeper_clearances_2018_2019',]].mean(axis=1)
complete_stats['average_throw_outs'] = complete_stats [['throw_outs_2015_2016','throw_outs_2016_2017','throw_outs_2017_2018','throw_outs_2018_2019',]].mean(axis=1)
complete_stats['average_goal_kicks'] = complete_stats [['goal_kicks_2015_2016','goal_kicks_2016_2017','goal_kicks_2017_2018','goal_kicks_2018_2019',]].mean(axis=1)

# %% [markdown]
# ## Positions & Columns

# %%
# Display list of positions in data
# -------------------------------------------
complete_stats["position"].value_counts()
# Out:
# Midfielder    265
# Defender      248
# Forward       168
# Goalkeeper     76
# Name: position, dtype: int64

# %%
# Print list of columns in DataFrame
# -------------------------------------------
print(complete_stats.columns)
# Out:
# Index(['position', 'appearances_2015_2016', 'clean_sheets_2015_2016',
#        'goals_conceded_2015_2016', 'tackles_2015_2016',
#        'tackle_success_percentage_2015_2016', 'last_man_tackles_2015_2016',
#        'blocked_shots_2015_2016', 'interceptions_2015_2016',
#        'clearances_2015_2016',
#        ...
#        'average_shooting_accuracy_percentage', 'average_big_chances_missed',
#        'average_saves', 'average_penalties_saved', 'average_punches',
#        'average_high_claims', 'average_catches', 'average_sweeper_clearances',
#        'average_throw_outs', 'average_goal_kicks'],
#       dtype='object', length=255)

# %%
# Print list of columns in DataFrame for pasting to QuickDBD
# -------------------------------------------
for col_name in complete_stats.columns: 
    print(col_name)
# Out:
# position
# appearances_2015_2016
# clean_sheets_2015_2016
# goals_conceded_2015_2016
# tackles_2015_2016
# tackle_success_percentage_2015_2016
# last_man_tackles_2015_2016
# blocked_shots_2015_2016
# interceptions_2015_2016
# clearances_2015_2016
# headed_clearance_2015_2016
# clearances_off_line_2015_2016
# recoveries_2015_2016
# duels_won_2015_2016
# duels_lost_2015_2016
# successful_50_50s_2015_2016
# aerial_battles_won_2015_2016
# aerial_battles_lost_2015_2016
# own_goals_2015_2016
# errors_leading_to_goal_2015_2016
# assists_2015_2016
# passes_2015_2016
# passes_per_match_2015_2016
# big_chances_created_2015_2016
# crosses_2015_2016
# cross_accuracy_percentage_2015_2016
# through_balls_2015_2016
# accurate_long_balls_2015_2016
# yellow_cards_2015_2016
# red_cards_2015_2016
# fouls_2015_2016
# offsides_2015_2016
# goals_2015_2016
# headed_goals_2015_2016
# goals_with_right_foot_2015_2016
# goals_with_left_foot_2015_2016
# hit_woodwork_2015_2016
# goals_per_match_2015_2016
# penalties_scored_2015_2016
# freekicks_scored_2015_2016
# shots_2015_2016
# shots_on_target_2015_2016
# shooting_accuracy_percentage_2015_2016
# big_chances_missed_2015_2016
# saves_2015_2016
# penalties_saved_2015_2016
# punches_2015_2016
# high_claims_2015_2016
# catches_2015_2016
# sweeper_clearances_2015_2016
# throw_outs_2015_2016
# goal_kicks_2015_2016
# appearances_2016_2017
# clean_sheets_2016_2017
# goals_conceded_2016_2017
# tackles_2016_2017
# tackle_success_percentage_2016_2017
# last_man_tackles_2016_2017
# blocked_shots_2016_2017
# interceptions_2016_2017
# clearances_2016_2017
# headed_clearance_2016_2017
# clearances_off_line_2016_2017
# recoveries_2016_2017
# duels_won_2016_2017
# duels_lost_2016_2017
# successful_50_50s_2016_2017
# aerial_battles_won_2016_2017
# aerial_battles_lost_2016_2017
# own_goals_2016_2017
# errors_leading_to_goal_2016_2017
# assists_2016_2017
# passes_2016_2017
# passes_per_match_2016_2017
# big_chances_created_2016_2017
# crosses_2016_2017
# cross_accuracy_percentage_2016_2017
# through_balls_2016_2017
# accurate_long_balls_2016_2017
# yellow_cards_2016_2017
# red_cards_2016_2017
# fouls_2016_2017
# offsides_2016_2017
# goals_2016_2017
# headed_goals_2016_2017
# goals_with_right_foot_2016_2017
# goals_with_left_foot_2016_2017
# hit_woodwork_2016_2017
# goals_per_match_2016_2017
# penalties_scored_2016_2017
# freekicks_scored_2016_2017
# shots_2016_2017
# shots_on_target_2016_2017
# shooting_accuracy_percentage_2016_2017
# big_chances_missed_2016_2017
# saves_2016_2017
# penalties_saved_2016_2017
# punches_2016_2017
# high_claims_2016_2017
# catches_2016_2017
# sweeper_clearances_2016_2017
# throw_outs_2016_2017
# goal_kicks_2016_2017
# appearances_2017_2018
# clean_sheets_2017_2018
# goals_conceded_2017_2018
# tackles_2017_2018
# tackle_success_percentage_2017_2018
# last_man_tackles_2017_2018
# blocked_shots_2017_2018
# interceptions_2017_2018
# clearances_2017_2018
# headed_clearance_2017_2018
# clearances_off_line_2017_2018
# recoveries_2017_2018
# duels_won_2017_2018
# duels_lost_2017_2018
# successful_50_50s_2017_2018
# aerial_battles_won_2017_2018
# aerial_battles_lost_2017_2018
# own_goals_2017_2018
# errors_leading_to_goal_2017_2018
# assists_2017_2018
# passes_2017_2018
# passes_per_match_2017_2018
# big_chances_created_2017_2018
# crosses_2017_2018
# cross_accuracy_percentage_2017_2018
# through_balls_2017_2018
# accurate_long_balls_2017_2018
# yellow_cards_2017_2018
# red_cards_2017_2018
# fouls_2017_2018
# offsides_2017_2018
# goals_2017_2018
# headed_goals_2017_2018
# goals_with_right_foot_2017_2018
# goals_with_left_foot_2017_2018
# hit_woodwork_2017_2018
# goals_per_match_2017_2018
# penalties_scored_2017_2018
# freekicks_scored_2017_2018
# shots_2017_2018
# shots_on_target_2017_2018
# shooting_accuracy_percentage_2017_2018
# big_chances_missed_2017_2018
# saves_2017_2018
# penalties_saved_2017_2018
# punches_2017_2018
# high_claims_2017_2018
# catches_2017_2018
# sweeper_clearances_2017_2018
# throw_outs_2017_2018
# goal_kicks_2017_2018
# appearances_2018_2019
# clean_sheets_2018_2019
# goals_conceded_2018_2019
# tackles_2018_2019
# tackle_success_percentage_2018_2019
# last_man_tackles_2018_2019
# blocked_shots_2018_2019
# interceptions_2018_2019
# clearances_2018_2019
# headed_clearance_2018_2019
# clearances_off_line_2018_2019
# recoveries_2018_2019
# duels_won_2018_2019
# duels_lost_2018_2019
# successful_50_50s_2018_2019
# aerial_battles_won_2018_2019
# aerial_battles_lost_2018_2019
# own_goals_2018_2019
# errors_leading_to_goal_2018_2019
# assists_2018_2019
# passes_2018_2019
# passes_per_match_2018_2019
# big_chances_created_2018_2019
# crosses_2018_2019
# cross_accuracy_percentage_2018_2019
# through_balls_2018_2019
# accurate_long_balls_2018_2019
# yellow_cards_2018_2019
# red_cards_2018_2019
# fouls_2018_2019
# offsides_2018_2019
# goals_2018_2019
# headed_goals_2018_2019
# goals_with_right_foot_2018_2019
# goals_with_left_foot_2018_2019
# hit_woodwork_2018_2019
# goals_per_match_2018_2019
# penalties_scored_2018_2019
# freekicks_scored_2018_2019
# shots_2018_2019
# shots_on_target_2018_2019
# shooting_accuracy_percentage_2018_2019
# big_chances_missed_2018_2019
# saves_2018_2019
# penalties_saved_2018_2019
# punches_2018_2019
# high_claims_2018_2019
# catches_2018_2019
# sweeper_clearances_2018_2019
# throw_outs_2018_2019
# goal_kicks_2018_2019
# average_appearances
# average_clean_sheets
# average_goals_conceded
# average_tackles
# average_tackle_success_percentage
# average_last_man_tackles
# average_blocked_shots
# average_interceptions
# average_clearances
# average_headed_clearance
# average_clearances_off_line
# average_recoveries
# average_duels_won
# average_duels_lost
# average_successful_50_50s
# average_aerial_battles_won
# average_aerial_battles_lost
# average_own_goals
# average_errors_leading_to_goal
# average_assists
# average_passes
# average_passes_per_match
# average_big_chances_created
# average_crosses
# average_cross_accuracy_percentage
# average_through_balls
# average_accurate_long_balls
# average_yellow_cards
# average_fouls
# average_offsides
# average_goals
# average_headed_goals
# average_goals_with_right_foot
# average_goals_with_left_foot
# average_hit_woodwork
# average_goals_per_match
# average_penalties_scored
# average_freekicks_scored
# average_shots
# average_shots_on_target
# average_shooting_accuracy_percentage
# average_big_chances_missed
# average_saves
# average_penalties_saved
# average_punches
# average_high_claims
# average_catches
# average_sweeper_clearances
# average_throw_outs
# average_goal_kicks

# %%
avg_complete_data = complete_stats[['position','average_appearances',
                                    'average_clean_sheets',
                                    'average_goals_conceded',
                                    'average_tackles',
                                    'average_tackle_success_percentage',
                                    'average_last_man_tackles',
                                    'average_blocked_shots',
                                    'average_interceptions',
                                    'average_clearances',
                                    'average_headed_clearance',
                                    'average_clearances_off_line',
                                    'average_recoveries',
                                    'average_duels_won',
                                    'average_duels_lost',
                                    'average_successful_50_50s',
                                    'average_aerial_battles_won',
                                    'average_aerial_battles_lost',
                                    'average_own_goals',
                                    'average_errors_leading_to_goal',
                                    'average_assists',
                                    'average_passes',
                                    'average_passes_per_match',
                                    'average_big_chances_created',
                                    'average_crosses',
                                    'average_cross_accuracy_percentage',
                                    'average_through_balls',
                                    'average_accurate_long_balls',
                                    'average_yellow_cards',
                                    'average_fouls',
                                    'average_offsides',
                                    'average_goals',
                                    'average_headed_goals',
                                    'average_goals_with_right_foot',
                                    'average_goals_with_left_foot',
                                    'average_hit_woodwork',
                                    'average_goals_per_match',
                                    'average_penalties_scored',
                                    'average_freekicks_scored',
                                    'average_shots_on_target',
                                    'average_shooting_accuracy_percentage',
                                    'average_big_chances_missed',
                                    'average_saves',
                                    'average_penalties_saved',
                                    'average_punches',
                                    'average_high_claims',
                                    'average_catches',
                                    'average_sweeper_clearances',
                                    'average_throw_outs',
                                    'average_goal_kicks', 
                                   ]]

# %%
avg_complete_data
# Out:
#                       position  average_appearances  average_clean_sheets  \
# name
# Rolando Aarons      Midfielder                 10.0                   0.0
# Almen Abdi          Midfielder                 32.0                   0.0
# Abdul Rahman Baba     Defender                 15.0                   2.0
# Mehdi Abeid         Midfielder                  0.0                   0.0
# Tammy Abraham          Forward                  2.0                   0.0
# ...                        ...                  ...                   ...
# Mauro Zárate           Forward                 15.0                   0.0
# Gedion Zelalem      Midfielder                  0.0                   0.0
# Kurt Zouma            Defender                 23.0                   8.0
# Stéphane Zubar        Defender                  0.0                   0.0
# Bruno Zuculini      Midfielder                  0.0                   0.0
#
#                     average_goals_conceded  average_tackles  \
# name
# Rolando Aarons                         0.0             13.0
# Almen Abdi                             0.0             83.0
# Abdul Rahman Baba                     13.0             47.0
# Mehdi Abeid                            0.0              0.0
# Tammy Abraham                          0.0              0.0
# ...                                    ...              ...
# Mauro Zárate                           0.0             25.0
# Gedion Zelalem                         0.0              0.0
# Kurt Zouma                            26.0             30.0
# Stéphane Zubar                         0.0              0.0
# Bruno Zuculini                         0.0              0.0
#
#                     average_tackle_success_percentage  \
# name
# Rolando Aarons                                   77.0
# Almen Abdi                                       78.0
# Abdul Rahman Baba                                83.0
# Mehdi Abeid                                       0.0
# Tammy Abraham                                     0.0
# ...                                               ...
# Mauro Zárate                                      0.0
# Gedion Zelalem                                    0.0
# Kurt Zouma                                       73.0
# Stéphane Zubar                                    0.0
# Bruno Zuculini                                    0.0
#
#                     average_last_man_tackles  average_blocked_shots  \
# name
# Rolando Aarons                           0.0                    0.0
# Almen Abdi                               0.0                   10.0
# Abdul Rahman Baba                        0.0                    1.0
# Mehdi Abeid                              0.0                    0.0
# Tammy Abraham                            0.0                    1.0
# ...                                      ...                    ...
# Mauro Zárate                             0.0                    7.0
# Gedion Zelalem                           0.0                    0.0
# Kurt Zouma                               0.0                    3.0
# Stéphane Zubar                           0.0                    0.0
# Bruno Zuculini                           0.0                    0.0
#
#                     average_interceptions  average_clearances  ...  \
# name                                                           ...
# Rolando Aarons                        6.0                10.0  ...
# Almen Abdi                           32.0                24.0  ...
# Abdul Rahman Baba                    23.0                32.0  ...
# Mehdi Abeid                           0.0                 0.0  ...
# Tammy Abraham                         0.0                 0.0  ...
# ...                                   ...                 ...  ...
# Mauro Zárate                          7.0                 8.0  ...
# Gedion Zelalem                        0.0                 0.0  ...
# Kurt Zouma                           36.0               123.0  ...
# Stéphane Zubar                        0.0                 0.0  ...
# Bruno Zuculini                        0.0                 0.0  ...
#
#                     average_shooting_accuracy_percentage  \
# name
# Rolando Aarons                                      50.0
# Almen Abdi                                          26.0
# Abdul Rahman Baba                                    0.0
# Mehdi Abeid                                          0.0
# Tammy Abraham                                        0.0
# ...                                                  ...
# Mauro Zárate                                        38.0
# Gedion Zelalem                                       0.0
# Kurt Zouma                                           0.0
# Stéphane Zubar                                       0.0
# Bruno Zuculini                                       0.0
#
#                     average_big_chances_missed  average_saves  \
# name
# Rolando Aarons                             0.0            0.0
# Almen Abdi                                 1.0            0.0
# Abdul Rahman Baba                          0.0            0.0
# Mehdi Abeid                                0.0            0.0
# Tammy Abraham                              0.0            0.0
# ...                                        ...            ...
# Mauro Zárate                               1.0            0.0
# Gedion Zelalem                             0.0            0.0
# Kurt Zouma                                 0.0            0.0
# Stéphane Zubar                             0.0            0.0
# Bruno Zuculini                             0.0            0.0
#
#                     average_penalties_saved  average_punches  \
# name
# Rolando Aarons                          0.0              0.0
# Almen Abdi                              0.0              0.0
# Abdul Rahman Baba                       0.0              0.0
# Mehdi Abeid                             0.0              0.0
# Tammy Abraham                           0.0              0.0
# ...                                     ...              ...
# Mauro Zárate                            0.0              0.0
# Gedion Zelalem                          0.0              0.0
# Kurt Zouma                              0.0              0.0
# Stéphane Zubar                          0.0              0.0
# Bruno Zuculini                          0.0              0.0
#
#                     average_high_claims  average_catches  \
# name
# Rolando Aarons                      0.0              0.0
# Almen Abdi                          0.0              0.0
# Abdul Rahman Baba                   0.0              0.0
# Mehdi Abeid                         0.0              0.0
# Tammy Abraham                       0.0              0.0
# ...                                 ...              ...
# Mauro Zárate                        0.0              0.0
# Gedion Zelalem                      0.0              0.0
# Kurt Zouma                          0.0              0.0
# Stéphane Zubar                      0.0              0.0
# Bruno Zuculini                      0.0              0.0
#
#                     average_sweeper_clearances  average_throw_outs  \
# name
# Rolando Aarons                             0.0                 0.0
# Almen Abdi                                 0.0                 0.0
# Abdul Rahman Baba                          0.0                 0.0
# Mehdi Abeid                                0.0                 0.0
# Tammy Abraham                              0.0                 0.0
# ...                                        ...                 ...
# Mauro Zárate                               0.0                 0.0
# Gedion Zelalem                             0.0                 0.0
# Kurt Zouma                                 0.0                 0.0
# Stéphane Zubar                             0.0                 0.0
# Bruno Zuculini                             0.0                 0.0
#
#                     average_goal_kicks
# name
# Rolando Aarons                     0.0
# Almen Abdi                         0.0
# Abdul Rahman Baba                  0.0
# Mehdi Abeid                        0.0
# Tammy Abraham                      0.0
# ...                                ...
# Mauro Zárate                       0.0
# Gedion Zelalem                     0.0
# Kurt Zouma                         0.0
# Stéphane Zubar                     0.0
# Bruno Zuculini                     0.0
#
# [757 rows x 50 columns]

# %%
midfielder = avg_complete_data.loc[avg_complete_data['position']=='Midfielder']
defender = avg_complete_data.loc[avg_complete_data['position']=='Defender']
forward = avg_complete_data.loc[avg_complete_data['position']=='Forward']
goalkeeper = avg_complete_data.loc[avg_complete_data['position']=='Goalkeeper']

# %%
# Save DataFrame to csv file
# -------------------------------------------
midfielder.to_csv('Resources/midfielder_average.csv')
defender.to_csv('Resources/defender_average.csv')
forward.to_csv('Resources/forward_average.csv')
goalkeeper.to_csv('Resources/goalkeeper_average.csv')

# %% [markdown]
# ### Midfielder

# %%
midfielder_stats = midfielder[['position','average_appearances',
                                    'average_tackles',
                                    'average_tackle_success_percentage',
                                    'average_interceptions',
                                    'average_headed_clearance',
                                    'average_recoveries',
                                    'average_duels_won',
                                    'average_duels_lost',
                                    'average_successful_50_50s',
                                    'average_aerial_battles_won',
                                    'average_aerial_battles_lost',
                                    'average_own_goals',
                                    'average_errors_leading_to_goal',
                                    'average_assists',
                                    'average_passes',
                                    'average_passes_per_match',
                                    'average_big_chances_created',
                                    'average_crosses',
                                    'average_cross_accuracy_percentage',
                                    'average_through_balls',
                                    'average_accurate_long_balls',
                                    'average_yellow_cards',
                                    'average_fouls',
                                    'average_offsides',
                                    'average_goals',
                                    'average_headed_goals',
                                    'average_goals_with_right_foot',
                                    'average_goals_with_left_foot',
                                    'average_hit_woodwork',
                                    'average_goals_per_match',
                                    'average_penalties_scored',
                                    'average_freekicks_scored',
                                    'average_shots_on_target',
                                    'average_shooting_accuracy_percentage',
                                    'average_big_chances_missed',
                                   ]]

# %%
# Sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
midfielder_10 = midfielder_stats.sort_values(
    ["average_appearances", "average_assists", "average_big_chances_created", "average_passes_per_match", "average_successful_50_50s"], ascending=False)
midfielder_10.head(10)
# Out:
#                         position  average_appearances  average_tackles  \
# name
# Ross Barkley          Midfielder                 38.0             34.0
# Marc Albrighton       Midfielder                 38.0             65.0
# Juan Mata             Midfielder                 38.0             30.0
# Georginio Wijnaldum   Midfielder                 38.0             38.0
# Andrew Surman         Midfielder                 38.0             51.0
# Cesc Fàbregas         Midfielder                 37.0            103.0
# Moussa Sissoko        Midfielder                 37.0             54.0
# Matt Ritchie          Midfielder                 37.0             54.0
# Yann M'Vila           Midfielder                 37.0             99.0
# N'Golo Kanté          Midfielder                 37.0            175.0
#
#                       average_tackle_success_percentage  \
# name
# Ross Barkley                                       65.0
# Marc Albrighton                                    83.0
# Juan Mata                                          73.0
# Georginio Wijnaldum                                84.0
# Andrew Surman                                      67.0
# Cesc Fàbregas                                      73.0
# Moussa Sissoko                                     85.0
# Matt Ritchie                                       72.0
# Yann M'Vila                                        70.0
# N'Golo Kanté                                       71.0
#
#                       average_interceptions  average_headed_clearance  \
# name
# Ross Barkley                           17.0                      15.0
# Marc Albrighton                        49.0                       4.0
# Juan Mata                              23.0                       2.0
# Georginio Wijnaldum                    27.0                      10.0
# Andrew Surman                         109.0                      31.0
# Cesc Fàbregas                          23.0                       9.0
# Moussa Sissoko                         35.0                      21.0
# Matt Ritchie                           48.0                       7.0
# Yann M'Vila                            86.0                      31.0
# N'Golo Kanté                          156.0                      27.0
#
#                       average_recoveries  average_duels_won  \
# name
# Ross Barkley                       186.0              250.0
# Marc Albrighton                    214.0              154.0
# Juan Mata                          185.0               93.0
# Georginio Wijnaldum                228.0              164.0
# Andrew Surman                      240.0              134.0
# Cesc Fàbregas                      253.0              190.0
# Moussa Sissoko                     225.0              221.0
# Matt Ritchie                       202.0              149.0
# Yann M'Vila                        287.0              200.0
# N'Golo Kanté                       326.0              277.0
#
#                       average_duels_lost  average_successful_50_50s  ...  \
# name                                                                 ...
# Ross Barkley                       228.0                      116.0  ...
# Marc Albrighton                    172.0                       51.0  ...
# Juan Mata                          150.0                       30.0  ...
# Georginio Wijnaldum                177.0                       50.0  ...
# Andrew Surman                      149.0                       16.0  ...
# Cesc Fàbregas                      178.0                       23.0  ...
# Moussa Sissoko                     274.0                       83.0  ...
# Matt Ritchie                       192.0                       19.0  ...
# Yann M'Vila                        125.0                       15.0  ...
# N'Golo Kanté                       217.0                       47.0  ...
#
#                       average_headed_goals  average_goals_with_right_foot  \
# name
# Ross Barkley                           0.0                            7.0
# Marc Albrighton                        0.0                            1.0
# Juan Mata                              0.0                            1.0
# Georginio Wijnaldum                    4.0                            7.0
# Andrew Surman                          0.0                            0.0
# Cesc Fàbregas                          0.0                            5.0
# Moussa Sissoko                         0.0                            1.0
# Matt Ritchie                           1.0                            0.0
# Yann M'Vila                            0.0                            1.0
# N'Golo Kanté                           0.0                            1.0
#
#                       average_goals_with_left_foot  average_hit_woodwork  \
# name
# Ross Barkley                                   1.0                   5.0
# Marc Albrighton                                1.0                   1.0
# Juan Mata                                      5.0                   1.0
# Georginio Wijnaldum                            0.0                   0.0
# Andrew Surman                                  0.0                   1.0
# Cesc Fàbregas                                  0.0                   0.0
# Moussa Sissoko                                 0.0                   0.0
# Matt Ritchie                                   3.0                   1.0
# Yann M'Vila                                    0.0                   0.0
# N'Golo Kanté                                   0.0                   0.0
#
#                       average_goals_per_match  average_penalties_scored  \
# name
# Ross Barkley                             0.21                       2.0
# Marc Albrighton                          0.05                       0.0
# Juan Mata                                0.16                       1.0
# Georginio Wijnaldum                      0.29                       1.0
# Andrew Surman                            0.00                       0.0
# Cesc Fàbregas                            0.14                       2.0
# Moussa Sissoko                           0.03                       0.0
# Matt Ritchie                             0.11                       0.0
# Yann M'Vila                              0.03                       0.0
# N'Golo Kanté                             0.03                       0.0
#
#                       average_freekicks_scored  average_shots_on_target  \
# name
# Ross Barkley                               0.0                     29.0
# Marc Albrighton                            0.0                     11.0
# Juan Mata                                  1.0                     22.0
# Georginio Wijnaldum                        0.0                     29.0
# Andrew Surman                              0.0                      0.0
# Cesc Fàbregas                              1.0                     19.0
# Moussa Sissoko                             0.0                     12.0
# Matt Ritchie                               0.0                     17.0
# Yann M'Vila                                1.0                      5.0
# N'Golo Kanté                               0.0                      5.0
#
#                       average_shooting_accuracy_percentage  \
# name
# Ross Barkley                                          31.0
# Marc Albrighton                                       26.0
# Juan Mata                                             39.0
# Georginio Wijnaldum                                   54.0
# Andrew Surman                                          0.0
# Cesc Fàbregas                                         42.0
# Moussa Sissoko                                        32.0
# Matt Ritchie                                          22.0
# Yann M'Vila                                           17.0
# N'Golo Kanté                                          24.0
#
#                       average_big_chances_missed
# name
# Ross Barkley                                 7.0
# Marc Albrighton                              2.0
# Juan Mata                                    1.0
# Georginio Wijnaldum                          7.0
# Andrew Surman                                0.0
# Cesc Fàbregas                                1.0
# Moussa Sissoko                               3.0
# Matt Ritchie                                 2.0
# Yann M'Vila                                  0.0
# N'Golo Kanté                                 0.0
#
# [10 rows x 36 columns]

# %% [markdown]
# ### Defender

# %%
defender_stats = defender[['position','average_appearances',
                                    'average_clean_sheets',
                                    'average_tackles',
                                    'average_tackle_success_percentage',
                                    'average_last_man_tackles',
                                    'average_blocked_shots',
                                    'average_interceptions',
                                    'average_clearances',
                                    'average_headed_clearance',
                                    'average_clearances_off_line',
                                    'average_recoveries',
                                    'average_duels_won',
                                    'average_duels_lost',
                                    'average_successful_50_50s',
                                    'average_aerial_battles_won',
                                    'average_aerial_battles_lost',
                                    'average_own_goals',
                                    'average_errors_leading_to_goal',
                                    'average_assists',
                                    'average_passes',
                                    'average_passes_per_match',
                                    'average_big_chances_created',
                                    'average_crosses',
                                    'average_cross_accuracy_percentage',
                                    'average_through_balls',
                                    'average_accurate_long_balls',
                                    'average_yellow_cards',
                                    'average_fouls',
                                    'average_sweeper_clearances',
                                    'average_throw_outs',
                                    'average_goal_kicks', 
                                   ]]

# %%
# Sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
defender_10 = defender_stats.sort_values(
    ["average_appearances", "average_clean_sheets", "average_tackle_success_percentage", "average_clearances", "average_interceptions"], ascending=False)
defender_10.head(10)
# Out:
#                     position  average_appearances  average_clean_sheets  \
# name
# Wes Morgan          Defender                 38.0                  15.0
# Toby Alderweireld   Defender                 38.0                  13.0
# Craig Dawson        Defender                 38.0                  10.0
# Simon Francis       Defender                 38.0                   6.0
# Nacho Monreal       Defender                 37.0                  17.0
# José Fonte          Defender                 37.0                  11.0
# Aaron Cresswell     Defender                 37.0                  11.0
# César Azpilicueta   Defender                 37.0                   8.0
# Charlie Daniels     Defender                 37.0                   7.0
# Héctor Bellerín     Defender                 36.0                  18.0
#
#                     average_tackles  average_tackle_success_percentage  \
# name
# Wes Morgan                     51.0                               67.0
# Toby Alderweireld              45.0                               71.0
# Craig Dawson                   59.0                               69.0
# Simon Francis                 105.0                               73.0
# Nacho Monreal                  80.0                               70.0
# José Fonte                     53.0                               66.0
# Aaron Cresswell                38.0                               61.0
# César Azpilicueta             114.0                               75.0
# Charlie Daniels                75.0                               83.0
# Héctor Bellerín                58.0                               81.0
#
#                     average_last_man_tackles  average_blocked_shots  \
# name
# Wes Morgan                               0.0                    6.0
# Toby Alderweireld                        0.0                    8.0
# Craig Dawson                             0.0                   11.0
# Simon Francis                            0.0                    3.0
# Nacho Monreal                            0.0                    1.0
# José Fonte                               0.0                    2.0
# Aaron Cresswell                          0.0                   10.0
# César Azpilicueta                        0.0                    2.0
# Charlie Daniels                          0.0                    5.0
# Héctor Bellerín                          0.0                    5.0
#
#                     average_interceptions  average_clearances  \
# name
# Wes Morgan                           95.0               216.0
# Toby Alderweireld                    66.0               285.0
# Craig Dawson                         86.0               162.0
# Simon Francis                        88.0               206.0
# Nacho Monreal                       105.0               114.0
# José Fonte                           81.0               224.0
# Aaron Cresswell                      70.0                88.0
# César Azpilicueta                    86.0               102.0
# Charlie Daniels                      53.0                76.0
# Héctor Bellerín                      66.0                85.0
#
#                     average_headed_clearance  ...  \
# name                                          ...
# Wes Morgan                             110.0  ...
# Toby Alderweireld                      125.0  ...
# Craig Dawson                            93.0  ...
# Simon Francis                          118.0  ...
# Nacho Monreal                           50.0  ...
# José Fonte                              82.0  ...
# Aaron Cresswell                         41.0  ...
# César Azpilicueta                       32.0  ...
# Charlie Daniels                         33.0  ...
# Héctor Bellerín                         31.0  ...
#
#                     average_big_chances_created  average_crosses  \
# name
# Wes Morgan                                  0.0              0.0
# Toby Alderweireld                           1.0             16.0
# Craig Dawson                                3.0            130.0
# Simon Francis                               1.0            100.0
# Nacho Monreal                               2.0             99.0
# José Fonte                                  1.0              9.0
# Aaron Cresswell                             4.0            121.0
# César Azpilicueta                           3.0             57.0
# Charlie Daniels                             3.0            127.0
# Héctor Bellerín                             9.0            109.0
#
#                     average_cross_accuracy_percentage  average_through_balls  \
# name
# Wes Morgan                                        0.0                    2.0
# Toby Alderweireld                                13.0                    2.0
# Craig Dawson                                     22.0                    0.0
# Simon Francis                                    25.0                    0.0
# Nacho Monreal                                    20.0                    4.0
# José Fonte                                       33.0                    0.0
# Aaron Cresswell                                  26.0                    1.0
# César Azpilicueta                                19.0                    1.0
# Charlie Daniels                                  25.0                    1.0
# Héctor Bellerín                                  17.0                    9.0
#
#                     average_accurate_long_balls  average_yellow_cards  \
# name
# Wes Morgan                                 46.0                   3.0
# Toby Alderweireld                         238.0                   3.0
# Craig Dawson                               81.0                   3.0
# Simon Francis                             179.0                   5.0
# Nacho Monreal                              38.0                   1.0
# José Fonte                                136.0                   4.0
# Aaron Cresswell                           115.0                   1.0
# César Azpilicueta                         103.0                   7.0
# Charlie Daniels                            65.0                   2.0
# Héctor Bellerín                            33.0                   3.0
#
#                     average_fouls  average_sweeper_clearances  \
# name
# Wes Morgan                   27.0                         0.0
# Toby Alderweireld             9.0                         0.0
# Craig Dawson                 28.0                         0.0
# Simon Francis                35.0                         0.0
# Nacho Monreal                28.0                         0.0
# José Fonte                   21.0                         0.0
# Aaron Cresswell              22.0                         0.0
# César Azpilicueta            39.0                         0.0
# Charlie Daniels              10.0                         0.0
# Héctor Bellerín              19.0                         0.0
#
#                     average_throw_outs  average_goal_kicks
# name
# Wes Morgan                         0.0                 0.0
# Toby Alderweireld                  0.0                 0.0
# Craig Dawson                       0.0                 0.0
# Simon Francis                      0.0                 0.0
# Nacho Monreal                      0.0                 0.0
# José Fonte                         0.0                 0.0
# Aaron Cresswell                    0.0                 0.0
# César Azpilicueta                  0.0                 0.0
# Charlie Daniels                    0.0                 0.0
# Héctor Bellerín                    0.0                 0.0
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Forward

# %%
forward_stats = forward[['position','average_appearances',
                                    'average_tackles',
                                    'average_tackle_success_percentage',
                                    'average_interceptions',
                                    'average_recoveries',
                                    'average_duels_won',
                                    'average_duels_lost',
                                    'average_successful_50_50s',
                                    'average_aerial_battles_won',
                                    'average_aerial_battles_lost',
                                    'average_errors_leading_to_goal',
                                    'average_assists',
                                    'average_passes',
                                    'average_passes_per_match',
                                    'average_big_chances_created',
                                    'average_crosses',
                                    'average_cross_accuracy_percentage',
                                    'average_yellow_cards',
                                    'average_fouls',
                                    'average_offsides',
                                    'average_goals',
                                    'average_headed_goals',
                                    'average_goals_with_right_foot',
                                    'average_goals_with_left_foot',
                                    'average_hit_woodwork',
                                    'average_goals_per_match',
                                    'average_penalties_scored',
                                    'average_freekicks_scored',
                                    'average_shots_on_target',
                                    'average_shooting_accuracy_percentage',
                                    'average_big_chances_missed',
                                    'average_high_claims',
                                   ]]

# %%
# Sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
forward_10 = forward_stats.sort_values(
    ["average_appearances", "average_tackles", "average_interceptions", "average_goals_per_match", "average_shooting_accuracy_percentage"], ascending=False)
forward_10.head(10)
# Out:
#                 position  average_appearances  average_tackles  \
# name
# Troy Deeney      Forward                 38.0             49.0
# Olivier Giroud   Forward                 38.0             34.0
# Harry Kane       Forward                 38.0             29.0
# Sadio Mané       Forward                 37.0             54.0
# Riyad Mahrez     Forward                 37.0             53.0
# Odion Ighalo     Forward                 37.0             27.0
# Romelu Lukaku    Forward                 37.0             13.0
# Shinji Okazaki   Forward                 36.0             37.0
# Jamie Vardy      Forward                 36.0             35.0
# Willian          Forward                 35.0             42.0
#
#                  average_tackle_success_percentage  average_interceptions  \
# name
# Troy Deeney                                    0.0                   17.0
# Olivier Giroud                                 0.0                   10.0
# Harry Kane                                     0.0                   21.0
# Sadio Mané                                     0.0                   35.0
# Riyad Mahrez                                   0.0                   38.0
# Odion Ighalo                                   0.0                   15.0
# Romelu Lukaku                                  0.0                    0.0
# Shinji Okazaki                                 0.0                   15.0
# Jamie Vardy                                    0.0                   18.0
# Willian                                        0.0                   20.0
#
#                  average_recoveries  average_duels_won  average_duels_lost  \
# name
# Troy Deeney                     0.0                0.0                 0.0
# Olivier Giroud                  0.0                0.0                 0.0
# Harry Kane                      0.0                0.0                 0.0
# Sadio Mané                      0.0                0.0                 0.0
# Riyad Mahrez                    0.0                0.0                 0.0
# Odion Ighalo                    0.0                0.0                 0.0
# Romelu Lukaku                   0.0                0.0                 0.0
# Shinji Okazaki                  0.0                0.0                 0.0
# Jamie Vardy                     0.0                0.0                 0.0
# Willian                         0.0                0.0                 0.0
#
#                  average_successful_50_50s  average_aerial_battles_won  ...  \
# name                                                                    ...
# Troy Deeney                            0.0                         0.0  ...
# Olivier Giroud                         0.0                         0.0  ...
# Harry Kane                             0.0                         0.0  ...
# Sadio Mané                             0.0                         0.0  ...
# Riyad Mahrez                           0.0                         0.0  ...
# Odion Ighalo                           0.0                         0.0  ...
# Romelu Lukaku                          0.0                         0.0  ...
# Shinji Okazaki                         0.0                         0.0  ...
# Jamie Vardy                            0.0                         0.0  ...
# Willian                                0.0                         0.0  ...
#
#                  average_goals_with_right_foot  average_goals_with_left_foot  \
# name
# Troy Deeney                               10.0                           0.0
# Olivier Giroud                             1.0                           8.0
# Harry Kane                                19.0                           5.0
# Sadio Mané                                 6.0                           4.0
# Riyad Mahrez                               2.0                          13.0
# Odion Ighalo                              11.0                           3.0
# Romelu Lukaku                              4.0                          10.0
# Shinji Okazaki                             3.0                           1.0
# Jamie Vardy                               18.0                           4.0
# Willian                                    4.0                           1.0
#
#                  average_hit_woodwork  average_goals_per_match  \
# name
# Troy Deeney                       1.0                     0.34
# Olivier Giroud                    3.0                     0.42
# Harry Kane                        7.0                     0.66
# Sadio Mané                        1.0                     0.30
# Riyad Mahrez                      2.0                     0.46
# Odion Ighalo                      2.0                     0.41
# Romelu Lukaku                     7.0                     0.49
# Shinji Okazaki                    2.0                     0.14
# Jamie Vardy                       6.0                     0.67
# Willian                           0.0                     0.14
#
#                  average_penalties_scored  average_freekicks_scored  \
# name
# Troy Deeney                           6.0                       0.0
# Olivier Giroud                        1.0                       0.0
# Harry Kane                            5.0                       0.0
# Sadio Mané                            0.0                       0.0
# Riyad Mahrez                          4.0                       0.0
# Odion Ighalo                          0.0                       0.0
# Romelu Lukaku                         1.0                       0.0
# Shinji Okazaki                        0.0                       0.0
# Jamie Vardy                           5.0                       0.0
# Willian                               0.0                       2.0
#
#                  average_shots_on_target  \
# name
# Troy Deeney                         32.0
# Olivier Giroud                      43.0
# Harry Kane                          75.0
# Sadio Mané                          34.0
# Riyad Mahrez                        39.0
# Odion Ighalo                        48.0
# Romelu Lukaku                       48.0
# Shinji Okazaki                      12.0
# Jamie Vardy                         53.0
# Willian                             20.0
#
#                  average_shooting_accuracy_percentage  \
# name
# Troy Deeney                                      34.0
# Olivier Giroud                                   43.0
# Harry Kane                                       47.0
# Sadio Mané                                       40.0
# Riyad Mahrez                                     45.0
# Odion Ighalo                                     44.0
# Romelu Lukaku                                    41.0
# Shinji Okazaki                                   26.0
# Jamie Vardy                                      46.0
# Willian                                          33.0
#
#                  average_big_chances_missed  average_high_claims
# name
# Troy Deeney                             3.0                  0.0
# Olivier Giroud                         13.0                  0.0
# Harry Kane                             18.0                  0.0
# Sadio Mané                             12.0                  0.0
# Riyad Mahrez                            5.0                  0.0
# Odion Ighalo                           17.0                  0.0
# Romelu Lukaku                          18.0                  0.0
# Shinji Okazaki                          7.0                  0.0
# Jamie Vardy                            22.0                  0.0
# Willian                                 2.0                  0.0
#
# [10 rows x 33 columns]

# %% [markdown]
# ### Goalkeeper

# %%
goalkeeper_stats = goalkeeper[['position','average_appearances',
                                    'average_blocked_shots',
                                    'average_clearances',
                                    'average_clearances_off_line',
                                    'average_recoveries',
                                    'average_duels_won',
                                    'average_duels_lost',
                                    'average_own_goals',
                                    'average_errors_leading_to_goal',
                                    'average_assists',
                                    'average_passes',
                                    'average_passes_per_match',
                                    'average_big_chances_created',
                                    'average_yellow_cards',
                                    'average_fouls',
                                    'average_saves',
                                    'average_penalties_saved',
                                    'average_punches',
                                    'average_high_claims',
                                    'average_catches',
                                    'average_sweeper_clearances',
                                    'average_goal_kicks', 
                                   ]]

# %%
# Sort data in ascending order based on Average
# It is possible to sort based upon multiple columns
goalkeeper_10 = goalkeeper_stats.sort_values(
    ["average_appearances", "average_saves", "average_recoveries", "average_blocked_shots", "average_high_claims"], ascending=False)
goalkeeper_10.head(10)
# Out:
#                       position  average_appearances  average_blocked_shots  \
# name
# Heurelho Gomes      Goalkeeper                 38.0                    0.0
# Kasper Schmeichel   Goalkeeper                 38.0                    0.0
# Lukasz Fabianski    Goalkeeper                 37.0                    0.0
# Hugo Lloris         Goalkeeper                 37.0                    0.0
# Joe Hart            Goalkeeper                 35.0                    0.0
# Petr Cech           Goalkeeper                 34.0                    0.0
# David de Gea        Goalkeeper                 34.0                    0.0
# Simon Mignolet      Goalkeeper                 34.0                    0.0
# Adrián              Goalkeeper                 32.0                    0.0
# Artur Boruc         Goalkeeper                 32.0                    0.0
#
#                     average_clearances  average_clearances_off_line  \
# name
# Heurelho Gomes                     0.0                          0.0
# Kasper Schmeichel                  0.0                          0.0
# Lukasz Fabianski                   0.0                          0.0
# Hugo Lloris                        0.0                          0.0
# Joe Hart                           0.0                          0.0
# Petr Cech                          0.0                          0.0
# David de Gea                       0.0                          0.0
# Simon Mignolet                     0.0                          0.0
# Adrián                             0.0                          0.0
# Artur Boruc                        0.0                          0.0
#
#                     average_recoveries  average_duels_won  average_duels_lost  \
# name
# Heurelho Gomes                     0.0                0.0                 0.0
# Kasper Schmeichel                  0.0                0.0                 0.0
# Lukasz Fabianski                   0.0                0.0                 0.0
# Hugo Lloris                        0.0                0.0                 0.0
# Joe Hart                           0.0                0.0                 0.0
# Petr Cech                          0.0                0.0                 0.0
# David de Gea                       0.0                0.0                 0.0
# Simon Mignolet                     0.0                0.0                 0.0
# Adrián                             0.0                0.0                 0.0
# Artur Boruc                        0.0                0.0                 0.0
#
#                     average_own_goals  average_errors_leading_to_goal  ...  \
# name                                                                   ...
# Heurelho Gomes                    0.0                             3.0  ...
# Kasper Schmeichel                 0.0                             0.0  ...
# Lukasz Fabianski                  0.0                             4.0  ...
# Hugo Lloris                       0.0                             3.0  ...
# Joe Hart                          0.0                             1.0  ...
# Petr Cech                         0.0                             2.0  ...
# David de Gea                      1.0                             1.0  ...
# Simon Mignolet                    0.0                             4.0  ...
# Adrián                            0.0                             2.0  ...
# Artur Boruc                       0.0                             5.0  ...
#
#                     average_big_chances_created  average_yellow_cards  \
# name
# Heurelho Gomes                              0.0                   4.0
# Kasper Schmeichel                           0.0                   2.0
# Lukasz Fabianski                            0.0                   1.0
# Hugo Lloris                                 0.0                   0.0
# Joe Hart                                    0.0                   0.0
# Petr Cech                                   0.0                   0.0
# David de Gea                                0.0                   0.0
# Simon Mignolet                              0.0                   2.0
# Adrián                                      0.0                   1.0
# Artur Boruc                                 0.0                   2.0
#
#                     average_fouls  average_saves  average_penalties_saved  \
# name
# Heurelho Gomes                2.0          121.0                      3.0
# Kasper Schmeichel             0.0           99.0                      0.0
# Lukasz Fabianski              1.0          115.0                      0.0
# Hugo Lloris                   0.0           88.0                      0.0
# Joe Hart                      0.0           71.0                      0.0
# Petr Cech                     0.0          101.0                      0.0
# David de Gea                  0.0           83.0                      0.0
# Simon Mignolet                0.0           70.0                      1.0
# Adrián                        1.0           99.0                      2.0
# Artur Boruc                   1.0           77.0                      2.0
#
#                     average_punches  average_high_claims  average_catches  \
# name
# Heurelho Gomes                 66.0                 62.0             18.0
# Kasper Schmeichel              22.0                 47.0             15.0
# Lukasz Fabianski               34.0                 81.0             15.0
# Hugo Lloris                    27.0                 35.0             16.0
# Joe Hart                       39.0                 35.0              2.0
# Petr Cech                      19.0                 39.0             10.0
# David de Gea                   13.0                 20.0              6.0
# Simon Mignolet                 17.0                 32.0             15.0
# Adrián                         19.0                 40.0             11.0
# Artur Boruc                     8.0                 47.0              8.0
#
#                     average_sweeper_clearances  average_goal_kicks
# name
# Heurelho Gomes                            24.0               378.0
# Kasper Schmeichel                         46.0               324.0
# Lukasz Fabianski                          20.0               300.0
# Hugo Lloris                               40.0               247.0
# Joe Hart                                  26.0               221.0
# Petr Cech                                 33.0               248.0
# David de Gea                              18.0               287.0
# Simon Mignolet                            32.0               228.0
# Adrián                                    31.0               288.0
# Artur Boruc                               24.0               268.0
#
# [10 rows x 23 columns]

# %% [markdown]
# ## HTML Get Request

# %%
# Set headers to lowercase
# -------------------------------------------
html_request.columns = html_request.columns.str.lower()

# %%
# Set Name column as index
# -------------------------------------------
html_request.set_index('name', inplace=True)

# %%
# Display dataframe
# -------------------------------------------
html_request
# Out:
#                   nationality                  club
# name
# Harry Kane            England     Tottenham Hotspur
# Bruno Fernandes      Portugal                   NaN
# Mohamed Salah           Egypt          Liverpool FC
# Heung-min Son     South Korea     Tottenham Hotspur
# Patrick Bamford       England                   NaN
# ...                       ...                   ...
# Charly Musonda            NaN            Chelsea FC
# Jérémy Pied               NaN        Southampton FC
# Martin Olsson             NaN          Swansea City
# Allan Nyom                NaN  West Bromwich Albion
# Marvin Zeegelaar          NaN            Watford FC
#
# [542 rows x 2 columns]

# %% [markdown]
# ## Load to SQL DB

# %%
# Imports the method used for connecting to DBs
# ----------------------------------
from sqlalchemy import create_engine

# Create Database Connection
# ----------------------------------
# Creates a connection to our DB
engine = create_engine('postgresql://postgres:postgres@localhost:5432/EPL_db').connect()
complete_stats.to_sql('playerstats', engine)
html_request.to_sql('playernationality', engine)
midfielder.to_sql('midfielderstats', engine)
defender.to_sql('defenderstats', engine)
forward.to_sql('forwardstats', engine)
goalkeeper.to_sql('goalkeeperstats', engine)
